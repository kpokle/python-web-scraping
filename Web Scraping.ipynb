# %%
import wikipedia
import requests
from bs4 import BeautifulSoup
import time
import numpy as np
import pandas as pd
import os

# %%
html = requests.get('https://en.wikipedia.org/wiki/List_of_original_films_distributed_by_Netflix')

# %%
b = BeautifulSoup(html.text, 'lxml')

# %%
title = []
film_link = []
q = []

# %%
b
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of original films distributed by Netflix - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
   for i in b.find_all(name='table', class_='wikitable sortable jquery-tablesorter'):
        # get to the row of each film
        for j in i.find_all(name='tr'):
            #get just the title cell for each row.
            # contains the title and the URL
            for k in j.find_all(name='i'):
                # get within that cell to just get the words
                for link in k.find_all('a'):
                    # get the title and add to the list
                    #link
                    title.append(link['title'])
                    film_link.append(link['href'])
                    # get the link and add to that list
                    #links.append(link['href'])

# %%
time.sleep(1)
# Out:
# [<a href="/wiki/Beasts_of_No_Nation_(film)" title="Beasts of No Nation (film)">Beasts of No Nation</a>,
#  <a href="/wiki/Crouching_Tiger,_Hidden_Dragon:_Sword_of_Destiny" title="Crouching Tiger, Hidden Dragon: Sword of Destiny">Crouching Tiger, Hidden Dragon: Sword of Destiny</a>,
#  <a href="/wiki/The_Fundamentals_of_Caring" title="The Fundamentals of Caring">The Fundamentals of Caring</a>,
#  <a href="/wiki/Rebirth_(2016_film)" title="Rebirth (2016 film)">Rebirth</a>,
#  <a href="/wiki/Tallulah_(film)" title="Tallulah (film)">Tallulah</a>,
#  <a href="/wiki/XOXO_(film)" title="XOXO (film)">XOXO</a>,
#  <a href="/wiki/ARQ_(film)" title="ARQ (film)">ARQ</a>,
#  <a href="/wiki/The_Siege_of_Jadotville_(film)" title="The Siege of Jadotville (film)">The Siege of Jadotville</a>,
#  <a href="/wiki/I_Am_the_Pretty_Thing_That_Lives_in_the_House" title="I Am the Pretty Thing That Lives in the House">I Am the Pretty Thing That Lives in the House</a>,
# ...

# %%
full_links = ['https://en.wikipedia.org' + i for i in film_link]

# %%
possibles = ['Plot','Synopsis','Plot synopsis','Plot summary', 
             'Story','Plotline','The Beginning','Summary',
            'Content','Premise']

possibles_edit = [i + 'Edit' for i in possibles]

all_possibles = possibles + possibles_edit

# %%
title_links = list(zip(title, full_links))

# %%
for i in title_links:
    print(i)
# Out:
# ('Beasts of No Nation (film)', 'https://en.wikipedia.org/wiki/Beasts_of_No_Nation_(film)')
# ('Crouching Tiger, Hidden Dragon: Sword of Destiny', 'https://en.wikipedia.org/wiki/Crouching_Tiger,_Hidden_Dragon:_Sword_of_Destiny')
# ('The Fundamentals of Caring', 'https://en.wikipedia.org/wiki/The_Fundamentals_of_Caring')
# ('Rebirth (2016 film)', 'https://en.wikipedia.org/wiki/Rebirth_(2016_film)')
# ('Tallulah (film)', 'https://en.wikipedia.org/wiki/Tallulah_(film)')
# ('XOXO (film)', 'https://en.wikipedia.org/wiki/XOXO_(film)')
# ('ARQ (film)', 'https://en.wikipedia.org/wiki/ARQ_(film)')
# ('The Siege of Jadotville (film)', 'https://en.wikipedia.org/wiki/The_Siege_of_Jadotville_(film)')
# ('I Am the Pretty Thing That Lives in the House', 'https://en.wikipedia.org/wiki/I_Am_the_Pretty_Thing_That_Lives_in_the_House')
# ('7 Años', 'https://en.wikipedia.org/wiki/7_A%C3%B1os')
# ('Mercy (2016 film)', 'https://en.wikipedia.org/wiki/Mercy_(2016_film)')
# ...
